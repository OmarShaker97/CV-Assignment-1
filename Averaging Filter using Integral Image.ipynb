# %%
import matplotlib.pyplot as plt
from PIL import Image

img = Image.open("Cameraman_noise.bmp").convert("L")
 
integral_img = img.copy()

value = 0
w, h = img.size[0], img.size[1];
new_image = [[0 for x in range(h)] for y in range(w)] 
integral_array = [[0 for x in range(h)] for y in range(w)] 
 
# CALCULATE FOR ALL PIXELS THAT ARE ON THE LEFT    
for i in range (0,img.size[0]):
    value = 0
    for j in range (0,img.size[1]):
        value += img.getpixel((i, j))
        new_image[i][j] = value
        
# CALCULATE FOR ALL PIXELS THAT ARE ABOVE
for i in range (0,img.size[1]):
    value = 0
    for j in range (0,img.size[0]):
        value += new_image[j][i]
        integral_array[j][i] = value

integral_img = Image.open("Camera_Integ.jpg")
 
averaging_img = img.copy()

averaging_value = 0
 
for i in range (0,img.size[0]):
    for j in range (0,img.size[1]):
        try:
            top_pixel =  integral_array[i+1][j-2]
        except:
            top_pixel = 0
            
        try:
            left_pixel =  integral_array[i-2][j+1]
        except:
            left_pixel = 0
            
        try:
            top_left_pixel =  integral_array[i-2][j-2]
        except:
            top_left_pixel = 0
            
        try:
            bottom_right_pixel =  integral_array[i+1][j+1]
        except:
            bottom_right_pixel = 0
            
        averaging_value = (bottom_right_pixel - top_pixel - left_pixel + top_left_pixel)//9
        
        averaging_img.putpixel((i,j),averaging_value)
        
        
       
plt.imshow(averaging_img)
averaging_img.save('Camera_Filt_3.jpg')

# %%
import matplotlib.pyplot as plt
from PIL import Image

img = Image.open("Cameraman_noise.bmp").convert("L")
 
integral_img = img.copy()

value = 0
w, h = img.size[0], img.size[1];
new_image = [[0 for x in range(h)] for y in range(w)] 
integral_array = [[0 for x in range(h)] for y in range(w)] 
 
# CALCULATE FOR ALL PIXELS THAT ARE ON THE LEFT    
for i in range (0,img.size[0]):
    value = 0
    for j in range (0,img.size[1]):
        value += img.getpixel((i, j))
        new_image[i][j] = value
        
# CALCULATE FOR ALL PIXELS THAT ARE ABOVE
for i in range (0,img.size[1]):
    value = 0
    for j in range (0,img.size[0]):
        value += new_image[j][i]
        integral_array[j][i] = value

integral_img = Image.open("Camera_Integ.jpg")
 
averaging_img = img.copy()

averaging_value = 0
 
for i in range (0,img.size[0]):
    for j in range (0,img.size[1]):
        try:
            top_pixel =  integral_array[i+2][j-3]
        except:
            top_pixel = 0
            
        try:
            left_pixel =  integral_array[i-3][j+2]
        except:
            left_pixel = 0
            
        try:
            top_left_pixel =  integral_array[i-3][j-3]
        except:
            top_left_pixel = 0
            
        try:
            bottom_right_pixel =  integral_array[i+2][j+2]
        except:
            bottom_right_pixel = 0
            
        averaging_value = (bottom_right_pixel - top_pixel - left_pixel + top_left_pixel)//25
        
        averaging_img.putpixel((i,j),averaging_value)
        
        
       
plt.imshow(averaging_img)
averaging_img.save('Camera_Filt_5.jpg')
